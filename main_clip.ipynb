# %%
# Imports - basic
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms

# Configs
from config.config import SAE_Config
from config.config import CNN_Config

# Classes
from dataloader.load_data import LoadData
from model.cnn import ExplainableCNN
from model.sae import SAE
from trainer.trainer import Trainer

# Utils
from utils.hooks import Hooks
from utils.explanations import Explanations
from utils.clipActivations import Clip

# %%
device = torch.device("mps")

# %%
clip_model = Clip(model="ViT-B/32", concept_file='data/concepts/concepts.json', device=device, class_list=['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck'])

# %%
clip_model.collect_concepts()
clip_model.collect_embeddings()
clip_model.save_embeddings()
# Out:
# Saved safetensor file for airplane successfully!
# Saved safetensor file for automobile successfully!
# Saved safetensor file for bird successfully!
# Saved safetensor file for cat successfully!
# Saved safetensor file for deer successfully!
# Saved safetensor file for dog successfully!
# Saved safetensor file for frog successfully!
# Saved safetensor file for horse successfully!
# Saved safetensor file for ship successfully!
# Saved safetensor file for truck successfully!

# %%
class_list=['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

for cls in class_list:
    clip_model.create_permutations(cls, 4000)
# Out:
# Generating 4000 permutations for airplane
# Saved json file for permutations of airplane successfully!
# Generating 4000 permutations for automobile
# Saved json file for permutations of automobile successfully!
# Generating 4000 permutations for bird
# Saved json file for permutations of bird successfully!
# Generating 4000 permutations for cat
# Saved json file for permutations of cat successfully!
# Generating 4000 permutations for deer
# Saved json file for permutations of deer successfully!
# Generating 4000 permutations for dog
# Saved json file for permutations of dog successfully!
# Generating 4000 permutations for frog
# Saved json file for permutations of frog successfully!
# Generating 4000 permutations for horse
# Saved json file for permutations of horse successfully!
# Generating 4000 permutations for ship
# Saved json file for permutations of ship successfully!
# Generating 4000 permutations for truck
# Saved json file for permutations of truck successfully!
