# %%
# Imports - basic
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms

# Configs
from config.config import SAE_Config
from config.config import CNN_Config

# Classes
from dataloader.load_data import LoadData
from model.cnn import ExplainableCNN
from model.sae import SAE
from trainer.trainer import Trainer

# Utils
from utils.hooks import Hooks
from utils.explanations import Explanations
from utils.clipActivations import Clip

# %%
device = torch.device("mps")

# %%
clip_model = Clip(model="ViT-B/32", concept_file='data/concepts/concepts.json', device=device, class_list=['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck'])

# %%
clip_model.collect_concepts()
clip_model.collect_embeddings()
clip_model.save_embeddings()
# Out:
# Saved safetensor file for airplane successfully!
# Saved safetensor file for automobile successfully!
# Saved safetensor file for bird successfully!
# Saved safetensor file for cat successfully!
# Saved safetensor file for deer successfully!
# Saved safetensor file for dog successfully!
# Saved safetensor file for frog successfully!
# Saved safetensor file for horse successfully!
# Saved safetensor file for ship successfully!
# Saved safetensor file for truck successfully!

# %%
clip_model.create_permutations()
# Out:
# ['air traffic tower', 'aircraft livery', 'airline logo', 'airport lighting', 'airport terminal', 'airport vehicles', 'antennas', 'ascending flight', 'backlit airplane', 'banking turn', 'blue sky', 'blurred background', 'cargo door', 'cargo plane', 'city background', 'clear weather', 'close distance scale', 'close-up airplane', 'cloud formations', 'cloudy sky', 'cockpit window', 'colored stripes', 'commercial airliner', 'contrails', 'cropped airplane', 'dawn lighting', 'descending flight', 'distant airplane', 'dusk lighting', 'emergency exit doors', 'exhaust nozzle', 'extended landing gear', 'far distance scale', 'fighter jet', 'foggy background', 'frontal view', 'fuselage', 'ground shadow', 'hangar', 'high altitude', 'high contrast sky', 'horizontal stabilizer', 'jet aircraft', 'jet engines', 'landing gear', 'landing pose', 'lens flare', 'low altitude', 'metallic reflection', 'motion blur', 'mountain background', 'navigation lights', 'night sky', 'nose cone', 'ocean background', 'painted tail art', 'partial occlusion', 'passenger windows', 'propeller plane', 'radar dome', 'rain streaks', 'rear view', 'reflections', 'retracted landing gear', 'runway', 'runway markings', 'rural background', 'shadow on clouds', 'sharp focus airplane', 'side profile', 'silhouette', 'smoke trail', 'snow background', 'storm clouds', 'strobe lights', 'sun glare', 'sunset sky', 'tail fin', 'takeoff pose', 'tarmac', 'taxiway lines', 'top-down view', 'turbine intake', 'underside view', 'white paint', 'windows row', 'wing flaps', 'wing shadow', 'winglets', 'wingspan']
